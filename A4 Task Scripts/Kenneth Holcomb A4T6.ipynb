# %% [markdown]
# # Contents
# 1. Question 3
# 2. Question 4
# 3. Question 5
# 4. Question 6
# 5. Question 7

# %% [markdown]
# # Question 3

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
#Importing path
path = r'C:\Users\Owner\OneDrive\Desktop\Data Analytics\Achievement 4\11-2022 Instacart Basket Analysis'

# %%
#Importing orders_products_combined df
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # Question 4

# %%
#Checking the shape of orders_products_combined
df_ords_prods_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# # Question 5

# %%
#Importing df_prods_checked
df_prods_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0  order_id  customer_id  order_number  orders_day_of_week  \
# 0           0   2539329            1             1                   2
# 1           0   2539329            1             1                   2
# 2           0   2539329            1             1                   2
# 3           0   2539329            1             1                   2
# 4           0   2539329            1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
df_ords_prods_combined1 = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
#Merging df_ords_prods_combined1 with df_prods_checked using product_id
df_ords_prods_merged = df_ords_prods_combined1.merge(df_prods_checked, on = ['product_id'], indicator = True)

# %% [markdown]
# # Question 6

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0_x  order_id  customer_id  order_number  \
# 0                    0   2539329            1             1
# 1                    1   2398795            1             2
# 2                    2    473747            1             3
# 3                    3   2254736            1             4
# 4                    4    431534            1             5
# ...                ...       ...          ...           ...
# 32404854       3360493   1320836       202557            17
# 32404855       3360494     31526       202557            18
# 32404856       3376038    758936       203436             1
# 32404857       3376039   2745165       203436             2
# 32404858       3408036   3093936       205420             1
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# 1                          3                  7                    15.0
# ...

# %%
#Checking value count on merged dataframes
df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # Question 7

# %%
#Exporting df_ords_prods_merged to pickle file
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
