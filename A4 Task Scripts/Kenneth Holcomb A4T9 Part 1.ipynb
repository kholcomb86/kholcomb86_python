# %% [markdown]
# # Contents
# 1. Question 3
# 2. Question 4
# 3. Question 5
# 4. Question 6

# %% [markdown]
# # Question 3

# %%
#Import libraries and dataset
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Owner\OneDrive\Desktop\Data Analytics\Achievement 4\11-2022 Instacart Basket Analysis'

# %%
customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
customers.head(15)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %%
customers.shape
# Out:
# (206209, 10)

# %% [markdown]
# # Question 4

# %%
#Wrangling Data-Dropping n_dependants from dataframe
customers1 = customers.drop(columns = ['n_dependants'])

# %%
customers1.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#   fam_status  income
# 0    married  165665
# 1     single   59285
# 2    married   99568
# 3     single   42049
# 4    married   40374

# %%
#Renaming surnam, STATE, and fam_status
customers1.rename(columns = {'Surnam' : 'Last Name'}, inplace = True)

# %%
customers1.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
customers1.rename(columns = {'fam_status' : 'family_status'}, inplace = True)

# %%
customers1.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#   family_status  income
# 0       married  165665
# 1        single   59285
# 2       married   99568
# 3        single   42049
# 4       married   40374

# %% [markdown]
# # Question 5

# %%
#Check for missing values
customers1.isnull().sum()
# Out:
# user_id              0
# First Name       11259
# Last Name            0
# Gender               0
# State                0
# Age                  0
# date_joined          0
# family_status        0
# income               0
# dtype: int64

# %%
df_nan = customers1[customers1['First Name'].isnull() ==  True]

# %%
df_nan
# Out:
#         user_id First Name Last Name  Gender         State  Age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#        family_status  income
# ...

# %% [markdown]
# There are 11,259 missing entries, but they are all first names. This would have to be corrected at the source as it is valuable customer information. Although, it wouldn't be needed for anything in particular but to do things like loyalty programs. The rest of the data is intact, so I would keep the missing values.

# %%
#Finding duplicates
df_dups = customers1[customers1.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, family_status, income]
# Index: []

# %% [markdown]
# There are no duplicates.

# %%
#Finding mixed data types
for col in customers1.columns.tolist():
    weird = (customers1[[col]].applymap(type) != customers1[[col]].iloc
            [0].apply(type)).any(axis = 1)
    if len (customers1[weird]) > 0:
        print (col)
# Out:
# First Name

# %%
customers1['First Name'] = customers1['First Name'].astype('str')

# %%
#Finding mixed data types
for col in customers1.columns.tolist():
    weird = (customers1[[col]].applymap(type) != customers1[[col]].iloc
            [0].apply(type)).any(axis = 1)
    if len (customers1[weird]) > 0:
        print (col)

# %% [markdown]
# # Question 6

# %%
#Importing ords_prods_merged
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged2.pkl'))

# %%
ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  order_id  customer_id  order_number  orders_day_of_week  \
# 0             0   2539329            1             1                   2
# 1             1   2398795            1             2                   3
# 2             2    473747            1             3                   3
# 3             3   2254736            1             4                   4
# 4             4    431534            1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...  _merge    price_range_loc    busiest_days  \
# ...

# %%
customers1.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#   family_status  income
# 0       married  165665
# 1        single   59285
# 2       married   99568
# 3        single   42049
# 4       married   40374

# %%
ords_prods_merged.rename(columns = {'customer_id' : 'user_id'}, inplace = True)

# %%
ords_prods_merge = ords_prods_merged.drop(columns = ['_merge'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6372\4262413374.py in <module>
# ----> 1 ords_prods_merge = ords_prods_merged.drop(columns = ['_merge'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#Merging ords_prods_merge w/ customers1
df_cust_ords_prods_merged = ords_prods_merge.merge(customers1, on = 'user_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6372\1492198822.py in <module>
#       1 #Merging ords_prods_merge w/ customers1
# ----> 2 df_cust_ords_prods_merged = ords_prods_merge.merge(customers1, on = 'user_id', indicator = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
# ...

# %%
df_cust_ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...         frequency_flag First Name  Last Name  Gender  \
# ...

# %%
df_cust_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_cust_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_cust_merged.pkl'))
